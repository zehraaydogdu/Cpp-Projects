# %% [markdown]
# ## If-Else Yapısı
# C dilindekinden bir farkı yoktur.
# `if(5>4){`
#     `cout<<"Program calissin";`
#     `}`
# *if blogunun içi doğruysa ifade çalışır.*
# Bunun bir de if-else if versiyonu var.

# %% [markdown]
# ## Switch-Case Yapısı
# Örn: `int main(){`
#        `int gun;`
#        `cout<<"Lutfen bir gun giriniz: ";`
#        `cin>>gun;`
#        ` `
#        `switch(gun){`
#        `case 1: cout<<"Gunlerden Pazartesi;`
#        `break;`
#        `//Alta doğru diğer caseler devam eder.`
#        `//Eğer hiçbir koşula girmiyorsa: `
#        `default: `
#        `cout<<"Yanlis bir deger girdiniz";`
#        `break;`
#        `}`
