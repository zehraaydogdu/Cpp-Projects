# %% [markdown]
# # Diziler
# ## Tek Boyutlu Diziler
# C dilindekiyle aynı şekilde yazılır.

# %%
int main(){
    int sayilarim[10];
    char harfler[3]={'C', 'A', 'N'};
    cout << harfler[2];
}  
//Eğer böyle yazarsak C harfi bastırılır.
